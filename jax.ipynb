# %% [markdown]
# Imports

# %%
import xarray as xr
import jax

# %% [markdown]
# Load xarray Dataset from netCDF file

# %%
YEAR = 1970
ds = xr.open_dataset(f"ERA5_data/{YEAR}/data.nc", engine='h5netcdf')
ds.keys()
# Out:
# KeysView(<xarray.Dataset> Size: 4GB
# Dimensions:         (date: 12, pressure_level: 13, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B ...
#   * date            (date) int64 96B 19700101 19700201 ... 19701101 19701201
#   * pressure_level  (pressure_level) float64 104B 1e+03 925.0 ... 100.0 50.0
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     expver          (date) <U4 192B ...
# Data variables:
#     z               (date, pressure_level, latitude, longitude) float32 648MB ...
#     q               (date, pressure_level, latitude, longitude) float32 648MB ...
#     t               (date, pressure_level, latitude, longitude) float32 648MB ...
#     u               (date, pressure_level, latitude, longitude) float32 648MB ...
#     v               (date, pressure_level, latitude, longitude) float32 648MB ...
#     w               (date, pressure_level, latitude, longitude) float32 648MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-11-22T15:53 GRIB to CDM+CF via cfgrib-0.9.1...)

# %%
jax_array = jax.numpy.array(da.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:703, in dtype(x, canonicalize)
#     702 try:
# --> 703   dt = np.result_type(x)
#     704 except TypeError as err:
#
# TypeError: Cannot interpret '<bound method Mapping.values of <xarray.Dataset> Size: 3GB
# Dimensions:         (date: 120, pressure_level: 1, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B ...
#   * date            (date) int64 960B 20110101 20110201 ... 20201101 20201201
#   * pressure_level  (pressure_level) float64 8B 1e+03
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     expver          (date) <U4 2kB ...
# Data variables:
#     z               (date, pressure_level, latitude, longitude) float32 498MB ...
#     q               (date, pressure_level, latitude, longitude) float32 498MB ...
#     t               (date, pressure_level, latitude, longitude) float32 498MB ...
#     u               (date, pressure_level, latitude, longitude) float32 498MB ...
#     v               (date, pressure_level, latitude, longitude) float32 498MB ...
#     w               (date, pressure_level, latitude, longitude) float32 498MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-11-19T18:24 GRIB to CDM+CF via cfgrib-0.9.1...>' as a data type
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:5394, in array(object, dtype, copy, order, ndmin, device)
#    5393 try:
# -> 5394   dtype = dtypes._lattice_result_type(*leaves)[0] if leaves else dtypes.float_
#    5395 except TypeError:
#    5396   # This happens if, e.g. one of the entries is a memoryview object.
#    5397   # This is rare, so we only handle it if the normal path fails.
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:713, in _lattice_result_type(*args)
#     712 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 713   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     714   if len(dtypes) == 1:
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:713, in <genexpr>(.0)
#     712 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 713   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     714   if len(dtypes) == 1:
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:516, in _dtype_and_weaktype(value)
#     515 """Return a (dtype, weak_type) tuple for the given input."""
# --> 516 return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:705, in dtype(x, canonicalize)
#     704   except TypeError as err:
# --> 705     raise TypeError(f"Cannot determine dtype of {x}") from err
#     706 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
#
# TypeError: Cannot determine dtype of <bound method Mapping.values of <xarray.Dataset> Size: 3GB
# Dimensions:         (date: 120, pressure_level: 1, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B ...
#   * date            (date) int64 960B 20110101 20110201 ... 20201101 20201201
#   * pressure_level  (pressure_level) float64 8B 1e+03
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     expver          (date) <U4 2kB ...
# Data variables:
#     z               (date, pressure_level, latitude, longitude) float32 498MB ...
#     q               (date, pressure_level, latitude, longitude) float32 498MB ...
#     t               (date, pressure_level, latitude, longitude) float32 498MB ...
#     u               (date, pressure_level, latitude, longitude) float32 498MB ...
#     v               (date, pressure_level, latitude, longitude) float32 498MB ...
#     w               (date, pressure_level, latitude, longitude) float32 498MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-11-19T18:24 GRIB to CDM+CF via cfgrib-0.9.1...>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 jax_array = jax.numpy.array(da.values)
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:5399, in array(object, dtype, copy, order, ndmin, device)
#    5395   except TypeError:
#    5396     # This happens if, e.g. one of the entries is a memoryview object.
#    5397     # This is rare, so we only handle it if the normal path fails.
#    5398     leaves = [_convert_to_array_if_dtype_fails(leaf) for leaf in leaves]
# -> 5399     dtype = dtypes._lattice_result_type(*leaves)[0]
#    5401 if not weak_type:
#    5402   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:713, in _lattice_result_type(*args)
#     712 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 713   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     714   if len(dtypes) == 1:
#     715     out_dtype = dtypes[0]
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:713, in <genexpr>(.0)
#     712 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 713   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     714   if len(dtypes) == 1:
#     715     out_dtype = dtypes[0]
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:516, in _dtype_and_weaktype(value)
#     514 def _dtype_and_weaktype(value: Any) -> tuple[DType, bool]:
#     515   """Return a (dtype, weak_type) tuple for the given input."""
# --> 516   return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File /net/home/h04/hwhitby/ml-training/project/.cdsapivenv/lib/python3.11/site-packages/jax/_src/dtypes.py:707, in dtype(x, canonicalize)
#     705     raise TypeError(f"Cannot determine dtype of {x}") from err
#     706 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
# --> 707   raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#     708                   "type. Only arrays of numeric types are supported by JAX.")
#     709 # TODO(jakevdp): fix return type annotation and remove this ignore.
#     710 return canonicalize_dtype(dt, allow_extended_dtype=True) if canonicalize else dt
#
# TypeError: Value '<bound method Mapping.values of <xarray.Dataset> Size: 3GB
# Dimensions:         (date: 120, pressure_level: 1, latitude: 721,
#                      longitude: 1440)
# Coordinates:
#     number          int64 8B ...
#   * date            (date) int64 960B 20110101 20110201 ... 20201101 20201201
#   * pressure_level  (pressure_level) float64 8B 1e+03
#   * latitude        (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude       (longitude) float64 12kB 0.0 0.25 0.5 ... 359.2 359.5 359.8
#     expver          (date) <U4 2kB ...
# Data variables:
#     z               (date, pressure_level, latitude, longitude) float32 498MB ...
#     q               (date, pressure_level, latitude, longitude) float32 498MB ...
#     t               (date, pressure_level, latitude, longitude) float32 498MB ...
#     u               (date, pressure_level, latitude, longitude) float32 498MB ...
#     v               (date, pressure_level, latitude, longitude) float32 498MB ...
#     w               (date, pressure_level, latitude, longitude) float32 498MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-11-19T18:24 GRIB to CDM+CF via cfgrib-0.9.1...>' with dtype object is not a valid JAX array type. Only arrays of numeric types are supported by JAX.
